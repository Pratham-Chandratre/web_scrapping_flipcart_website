# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_page

# %%
flipcart_html = bs(flipcart_page , 'html.parser')  # Beautified data

# %%
productlink = "https://www.flipkart.com"+"/lg-80-cm-32-inch-hd-ready-led-smart-webos-tv/p/itm6207e6d122567?pid=TVSFTW4CSRW8PGDQ&lid=LSTTVSFTW4CSRW8PGDQSZQIO6&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=FkPickId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=ba608a68-8669-4f08-b951-0eefd01c892e.TVSFTW4CSRW8PGDQ.SEARCH&ppt=sp&ppn=sp&ssid=tz2l3vh0340000001689357263404&qH=c9a1fdac6e082dd8"

# %%
bigbox = flipcart_html.find_all("div", {"class" : "_1AtVbE col-12-12"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bigbox = flipcart_html.find_all("div", {"class" : "_1AtVbE col-12-12"})
#
# NameError: name 'flipcart_html' is not defined

# %%
len(bigbox)

# %%
del bigbox[0:3]

# %%
bigbox[0].div.div.div.a

# %%
# Now from this entire we have to extract href

# %%
bigbox[0].div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bigbox[0].div.div.div.a['href']
#
# NameError: name 'bigbox' is not defined

# %%
# To get into particular product page append the above url to flipcart url

# %%
"https://www.flipkart.com/search?q=" + bigbox[0].div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 "https://www.flipkart.com/search?q=" + bigbox[0].div.div.div.a['href']
#
# NameError: name 'bigbox' is not defined

# %%
for i in bigbox:
    print("https://www.flipkart.com/search?q=" + i.div.div.div.a['href'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for i in bigbox:
#       2     print("https://www.flipkart.com/search?q=" + i.div.div.div.a['href'])
#
# NameError: name 'bigbox' is not defined

# %%
productlink
# Out:
# 'https://www.flipkart.com/lg-80-cm-32-inch-hd-ready-led-smart-webos-tv/p/itm6207e6d122567?pid=TVSFTW4CSRW8PGDQ&lid=LSTTVSFTW4CSRW8PGDQSZQIO6&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=FkPickId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=ba608a68-8669-4f08-b951-0eefd01c892e.TVSFTW4CSRW8PGDQ.SEARCH&ppt=sp&ppn=sp&ssid=tz2l3vh0340000001689357263404&qH=c9a1fdac6e082dd8'

# %%
requests.get(productlink)
# Out:
# <Response [200]>

# %%
product_request = requests.get(productlink)

# %%
product_request
# Out:
# <Response [200]>

# %%
product_request.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
bs(product_request.text, 'html.parser')  #It will beautify little-bit
# Out:
# <!DOCTYPE html>
# ...

# %%
product_html = bs(product_request.text, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.find_all("div", {"class": "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text  # With .text you can get just person name not all things like class id, etc
# Out:
# 'Ravi'

# %%
for i in comment_box:
    print(i.div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Ravi
# ajay sahu
# Binita Ghosh
# Ravikumar  ROUTHU
# Amit  Gupta
# Suman Das
# Vijay Irlapati
# Sonagra Ashvin
# Rajesh  Jalagam
# Harish Kumar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
# By loop we can get all the names of users

# Now we have to scrap ratings

# %%
comment_box[0].div.div.div.div
# Out:
# <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 3
# 5
# 4
# 4
# 5
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
# Now we have to extract the header of our comment

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Terrific purchase'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Terrific purchase
# Wonderful
# Simply awesome
# Nice
# Brilliant
# Wonderful
# Very Good
# Terrific purchase
# Pretty good
# Best in the market!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
# Now we will extract all the large comments


comment_box[0].div.div.find_all("div", {"class": ""})[0].text
# Out:
# 'SuperREAD MORE'

# %%
for i in comment_box:
    print(i.div.div.find_all("div", {"class": ""})[0].text)
# Out:
# SuperREAD MORE
# Best quality LG TVREAD MORE
# Value for money awesome Just buy this tv and you won't regret And I really believe on LG products So just awesomeREAD MORE
# Good quality good productREAD MORE
# 1- Superb TV And outstanding Performance compared to its price.2 - Picture quality and sound quality is too good with its 10 w speaker.3 - Connectivity is very fast.4 - Those who are facing difficulty in sound and picture quality , use the hd setup box and hdmi cable to connect setup box and tv , then only you will get better experience of sound and picture quality.5 - Only one cons is that it has no Bluetooth connectivity.READ MORE
# I like it . Best tv . Value for money . Delivery is also quick, 1day installation ... Overall it is a good choice to buy this TV from Flipkart... Thnks Flipkart .READ MORE
# Beautiful Product and it’s best in this price range.. LG is best in electronics and Picture quality is awesome 👍READ MORE
# To goodREAD MORE
# ...
